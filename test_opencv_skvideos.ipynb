# %%
import keras
import numpy as np
import io
import os
import base64
from IPython.display import HTML

import skvideo
skvideo.setFFmpegPath("C:/Program Files/ffmpeg-4.1-win64-static/bin/")
import skvideo.io

import cv2
import json

def display_videos(name):
    video = io.open(name, 'r+b').read()
    encoded = base64.b64encode(video)
    return '''<video alt="test" controls>
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))
# Out:
# Using TensorFlow backend.
# value of _HAS_FFMPEG = 0
# FFmpeg verifie
# value of _HAS_FFMPEG = 1

# %%
# Out:
# value of _HAS_FFMPEG = 1
# c:\program files\python36\lib\site-packages\skvideo\__init__.py:309: UserWarning: ffmpeg/ffprobe not found in path: C:/Program Files (x86)/ffmpeg-4.1-win64-static/bin/
#   warnings.warn("ffmpeg/ffprobe not found in path: " + str(path), UserWarning)

# %%
skvideo.io.vwrite('test.mp4',  np.random.uniform(0,255,size=(100,100,100)))
HTML(display_videos('test.mp4'))
# Out:
# value of _HAS_FFMPEG = 1
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
assert False, "plop"
